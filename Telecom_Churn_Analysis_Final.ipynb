# %% [markdown]
# <a href="https://colab.research.google.com/github/KJPriyadharshini/TelecomChurnAnalysisPython/blob/main/Telecom_Churn_Analysis_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📉 Telecom Customer Churn Analysis: A Visual Storytelling Approach
#
# This project explores the churn behavior of telecom customers using Python-based data analysis and storytelling visuals.
# Through feature engineering and targeted visualizations, we uncover key drivers behind customer churn such as cost sensitivity, usage patterns, plan satisfaction, and customer service experience.
#
# The goal is to move beyond surface-level metrics and provide **business-ready insights** that support actionable churn reduction strategies.

# %%
#importing the required libraries
import gdown
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# %%
#importing the dataset
#https://drive.google.com/file/d/1JcEsT3AsPNjUEQqgC6TDipn_twbJNs-F/view?usp=drive_link

# Downloading the dataset in the drive
file_id = "1JcEsT3AsPNjUEQqgC6TDipn_twbJNs-F"
gdown.download(f"https://drive.google.com/uc?export=download&id={file_id}", "Telecom_Data.csv", quiet=False)

data = pd.read_csv('Telecom_Data.csv')
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1JcEsT3AsPNjUEQqgC6TDipn_twbJNs-F
# To: /content/Telecom_Data.csv
# 100%|██████████| 310k/310k [00:00<00:00, 44.8MB/s]

# %% [markdown]
# ## Data Exploration

# %%
#showsthebasicinformationaboutthedataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
#showsthenumberofuniquedatasincolumns
data.nunique()
# Out:
# state                       51
# account length             212
# area code                    3
# phone number              3333
# international plan           2
# voice mail plan              2
# number vmail messages       46
# total day minutes         1667
# total day calls            119
# total day charge          1667
# total eve minutes         1611
# total eve calls            123
# total eve charge          1440
# total night minutes       1591
# total night calls          120
# total night charge         933
# total intl minutes         162
# total intl calls            21
# total intl charge          162
# customer service calls      10
# churn                        2
# dtype: int64

# %%
#showsthestatisticsofnumericalcolums
data.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
#includesthecatogoricalcolumnsalso
data.describe(include='object')
# Out:
#        state phone number international plan voice mail plan
# count   3333         3333               3333            3333
# unique    51         3333                  2               2
# top       WV     400-4344                 no              no
# freq     106            1               3010            2411

# %% [markdown]
# ## Checking missing and duplicate values

# %%
#to show the duplicate values
#data.duplicated()
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [state, account length, area code, phone number, international plan, voice mail plan, number vmail messages, total day minutes, total day calls, total day charge, total eve minutes, total eve calls, total eve charge, total night minutes, total night calls, total night charge, total intl minutes, total intl calls, total intl charge, customer service calls, churn]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ## Feature Engineering

# %%
#total minutes used by customer
data['total_minutes'] = data['total day minutes'] + data['total eve minutes'] + data['total night minutes'] + data['total intl minutes']

#total calls
data['total_calls'] = data['total day calls'] + data['total eve calls'] + data['total night calls'] + data['total intl calls']

#total calls
data['total_charge'] = data['total day charge'] + data['total eve charge'] + data['total night charge'] + data['total intl charge']

#average call duration calculated and handled to replace Nan with 0
data['avg_call_duration'] = data['total_minutes'] / data['total_calls']
data['avg_call_duration'] = data['avg_call_duration'].replace([np.inf, -np.inf], np.nan).fillna(0)

#to compare if customers without intl plan engage in intl calls
data['is_international_user'] = data['total intl minutes'].apply(lambda x: 1 if x > 0 else 0)

#engagemt of cusotmer vs churn
threshold = data['total_minutes'].quantile(0.75)
data['is_heavy_user'] = data['total_minutes'].apply(lambda x: 1 if x > threshold else 0)

#creating bucket for account length
def bucket_tenure(length):
    if length < 60:
        return 'Short-term'
    elif 60 <= length < 120:
        return 'Mid-term'
    else:
        return 'Long-term'

data['tenure_group'] = data['account length'].apply(bucket_tenure)

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total intl charge  customer service calls  churn  \
# ...

# %% [markdown]
# ## **VISUAL ANALYSIS**

# %% [markdown]
# #### Analysing the churn variable

# %%
import matplotlib.pyplot as plt

# Step 1: Get churn counts
churn_counts = data['churn'].value_counts()
labels = ['Not Churned', 'Churned']
colors = ['#617891', '#D5B893']  # pastel pink and teal

# Optional: Show value counts before the plot
churn_df = churn_counts.rename_axis('Churn').reset_index(name='Count')
display(churn_df)

# Step 2: Plot donut-style pie chart
plt.figure(figsize=(8, 5))  # make it clean and centered

plt.pie(
    churn_counts,
    labels=labels,
    colors=colors,
    startangle=60,
    shadow=True,
    radius=0.85,
    explode=(0, 0.08),
    autopct='%1.2f%%',
    pctdistance=0.75,
    textprops={'fontsize': 12, 'color': 'black'}
)

# Step 3: Add white circle to make it a donut
centre_circle = plt.Circle((0, 0), 0.45, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Step 4: Title and layout
plt.title('Churned vs Not Churned Customers', fontsize=14, fontweight='bold')
plt.savefig('churn_vs_unchurn.png', bbox_inches='tight', dpi=300)
plt.tight_layout()
plt.show()
# Out:
#    Churn  Count
# 0  False   2850
# 1   True    483

# %% [markdown]
# ### Insight 1: Overall Churn Distribution
#
# The donut chart shows that out of 3,333 customers, only 14% have churned, while 86% have remained active.
# This indicates a highly imbalanced churn scenario, where the majority of customers are retained.
# Such imbalance can affect how we interpret feature impact — emphasizing the need for careful analysis of churn drivers beyond raw numbers.

# %% [markdown]
# #### By Active Plans

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Detect churn classes (handles 'yes'/'no' or 1/0)
churn_classes = sorted(data['churn'].unique(), key=lambda x: str(x))
churn_labels = [str(c).capitalize() for c in churn_classes]

# Setup subplots
fig, axes = plt.subplots(1, 2, figsize=(8, 5), sharey=True)

# ---- Helper Function for Annotating Bars ----
def annotate_bars(ax, groupby_col):
    # Compute % churn/non-churn
    churn_table = data.groupby(groupby_col)['churn'].value_counts(normalize=True).unstack().fillna(0) * 100

    # Annotate all bars
    for container_idx, container in enumerate(ax.containers):
        for i, bar in enumerate(container):
            height = bar.get_height()
            percent = churn_table.iloc[i, container_idx]
            ax.annotate(f"{percent:.1f}%",
                        (bar.get_x() + bar.get_width() / 2, height + 10),
                        ha='center', fontsize=10, fontweight='bold')

# ---- Plot 1: International Plan ----
sns.countplot(data=data, x='international plan', hue='churn', ax=axes[0], palette = colors)
axes[0].set_title('Churn by International Plan', fontsize=10, fontweight='bold')
axes[0].set_xlabel('International Plan')
axes[0].set_ylabel('Number of Customers')
axes[0].legend(title='Churn', labels=churn_labels)
annotate_bars(axes[0], 'international plan')

# ---- Plot 2: Voice Mail Plan ----
sns.countplot(data=data, x='voice mail plan', hue='churn', ax=axes[1], palette=colors, legend = True)
axes[1].set_title('Churn by Voice Mail Plan', fontsize=10, fontweight='bold')
axes[1].set_xlabel('Voice Mail Plan')
axes[1].set_ylabel('')
axes[1].legend_.remove()
annotate_bars(axes[1], 'voice mail plan')

# Title & layout
plt.suptitle('Churn Distribution by Active Plans', fontsize=12, fontweight='bold')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# ### Insight 2: Churn by Active Plans (International & Voicemail)
#
# The churn distribution across active plans reveals that customers with an international plan exhibit a higher churn rate compared to those without one — despite having lower overall volume.
# This suggests that international plan holders may be more price-sensitive, possibly due to higher associated costs.
#
# Similarly, customers with a voicemail plan also show a slightly higher churn rate than those without it, even though the majority of users do not subscribe to voicemail.
# This pattern could indicate that the perceived value of these add-ons may not justify their cost, prompting customer exits.

# %% [markdown]
# #### Regional Analysis

# %%
# List of valid US states
valid_states = set([
    'AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID',
    'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS',
    'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK',
    'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV',
    'WI', 'WY'
])

# Check if there are any unexpected state codes
unexpected_states = set(data['state'].unique()) - valid_states
print("⚠️ Unexpected codes in your data:", unexpected_states)
# Out:
# ⚠️ Unexpected codes in your data: {'DC'}

# %%
import plotly.express as px
import pandas as pd

# STEP 1: Ensure state codes are uppercase strings
data['state'] = data['state'].astype(str).str.upper()

# STEP 2: Filter churned customers (handles various formats)
churned = data[data['churn'].isin(['yes', 'Yes', 1, True])].copy()

# STEP 3: Remove problematic state codes like 'DC'
churned = churned[churned['state'] != 'DC']

# STEP 4: Count churned customers by state
churn_by_state = churned['state'].value_counts().reset_index()
churn_by_state.columns = ['state', 'churn_count']

# STEP 5: Plot the Choropleth map
fig = px.choropleth(
    churn_by_state,
    locations='state',
    locationmode='USA-states',
    color='churn_count',
    scope='usa',
    color_continuous_scale= ['#D5B893','#617891'],
    title='Churn Count by State (USA)'
)

# Optional: Styling
fig.update_layout(
    title_x=0.5,
    title_font=dict(size=15, family='Arial', weight = 'bold'),
    geo=dict(bgcolor='rgba(0,0,0,0)')
)
plt.savefig('choropleth_map.png', bbox_inches='tight', dpi=300)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Insight 3: Geographic Distribution of Churn (Choropleth Map)
#
# The choropleth map of churn counts across U.S. states reveals that churn is geographically neutral, with no significant regional concentration.
# This indicates that location is not a key driver of churn in this dataset.
#
# Instead, churn behavior is likely influenced by individual customer factors such as usage patterns, plan types, and service experience — rather than external regional variables.

# %% [markdown]
# #### Analysis by the type of user

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Get churn counts by heavy user flag
churn_counts = data.groupby('is_heavy_user')['churn'].value_counts().unstack().fillna(0)
churn_counts.columns = ['not_churned', 'churned']

# Set up plot
fig, ax = plt.subplots(figsize=(8, 5))
churn_counts.plot(kind='bar', ax=ax, color= ['#617891', '#D5B893'] , edgecolor='black')

# Annotate actual counts
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        ax.annotate(f"{int(height)}",
                    (bar.get_x() + bar.get_width() / 2, height + 10),
                    ha='center', fontsize=10, fontweight='bold')

# Customize plot
ax.set_title('Churn Count: Heavy Users vs Regular Users', fontsize=12, fontweight='bold')
ax.set_xlabel('Is Heavy User (Top 25%)')
ax.set_ylabel('Number of Customers')
ax.set_xticklabels(['Regular User (0)', 'Heavy User (1)'], rotation=0)
ax.legend(title='Churn Status')
plt.savefig('heavyuser_chart.png', bbox_inches='tight', dpi=300)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insight 4: Churn by Usage Intensity (Heavy vs. Regular Users)
#
# The bar chart compares churn count between heavy users (top 25% by total call duration) and regular users.
# While the absolute number of churned customers is similar across both groups, the churn rate is notably higher among heavy users.
#
# This suggests that high engagement may be linked to dissatisfaction or perceived cost burden, especially if call usage translates to higher charges.
# Customers who use the service more may also be more sensitive to billing or service quality, leading to churn.

# %% [markdown]
# #### International Service Plans

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create the behavior flag using your existing column
data['intl_mismatch_user'] = data.apply(
    lambda row: 1 if row['international plan'] == 'no' and row['is_international_user'] == 1 else 0,
    axis=1
)

# Prepare data for visualization
churn_counts = data.groupby('intl_mismatch_user')['churn'].value_counts().unstack().fillna(0)
churn_counts.columns = ['not_churned', 'churned']
churn_counts['total'] = churn_counts.sum(axis=1)
churn_counts['churn_rate'] = churn_counts['churned'] / churn_counts['total'] * 100
churn_counts.index = ['No Mismatch', 'Has Mismatch']

# Plot
fig, ax = plt.subplots(figsize=(8, 5))

churn_counts[['not_churned', 'churned']].plot(
    kind='barh',
    stacked=True,
    color=['#617891', '#D5B893'],
    edgecolor='black',
    ax=ax
)

# Labels and title
ax.set_xlabel('Number of Customers')
ax.set_title('Churn Breakdown: Intl Callers Without Plan', fontweight = 'bold', fontsize = 12)
ax.legend(title='Churn Status', loc='lower right')

# Annotate churn rate
for idx, total in enumerate(churn_counts['total']):
    churn_rate = churn_counts['churn_rate'].iloc[idx]
    ax.annotate(f'{churn_rate:.1f}%',
                (total + 50, idx),  # x = just after bar, y = bar index
                va='center', fontsize=10, fontweight='bold')

# Clean y-axis labels
ax.set_yticklabels(churn_counts.index, rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insight 5: Churn Breakdown of International Callers Without a Plan
#
# Surprisingly, customers who have an international plan exhibit a higher churn rate than those who make international calls without a plan.
# This counterintuitive finding reinforces our earlier observation that international plan holders may be more likely to churn, potentially due to:
#
# Higher pricing that doesn’t match perceived value, or
#
# Dissatisfaction with the service quality tied to these plans.
#
# This suggests a need to re-evaluate the pricing or support experience for international plan users, as having a plan doesn't seem to reduce churn risk — in fact, it may be associated with increased risk.

# %% [markdown]
# #### By tenure Group

# %%
import matplotlib.pyplot as plt

# Filter only churned customers
churned_data = data[data['churn'] == True]

# Count churned customers by tenure group
tenure_churn_counts = churned_data['tenure_group'].value_counts()

# Pie chart
colors = ['#617891', '#D5B893', '#6F4D38']  # pink, orange, teal

plt.figure(figsize=(8,5))
plt.pie(
    tenure_churn_counts,
    labels=tenure_churn_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    shadow=True,
    explode=(0.05, 0.05, 0.05),
    colors=colors
)
plt.title('Churned Customers by Tenure Group', fontweight = 'bold', fontsize = 12)
plt.axis('equal')  # Equal aspect ratio ensures pie is circular
plt.savefig('piechart_tenure.png', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Insight 6: Churn Distribution by Tenure Group
#
# After segmenting customers by tenure, we observe that mid-term customers account for the largest share of churn (50%), followed by long-term customers (32%).
# Interestingly, short-term customers churn the least, despite typically being less loyal in most industries.
#
# This suggests that customers who have stayed long enough to experience the service more deeply are more likely to leave, potentially due to unmet expectations over time or growing dissatisfaction.
#
# It highlights a critical window: mid-tenure customers may require targeted retention strategies, such as loyalty perks or proactive support, to prevent churn after the initial “trial” phase.

# %% [markdown]
# #### Customer Service Analysis

# %%
import matplotlib.pyplot as plt

# Group by number of service calls and calculate churn rate
service_calls_churn = data.groupby('customer service calls')['churn'].value_counts(normalize=True).unstack().fillna(0)
display(service_calls_churn)
service_calls_churn.columns = ['Not Churned', 'Churned']
service_calls_churn['Churn Rate'] = service_calls_churn['Churned'] * 100

# Plot churn rate by number of customer service calls
plt.figure(figsize=(8, 5))
plt.plot(service_calls_churn.index, service_calls_churn['Churn Rate'], marker='o', color= '#D5B893', linewidth=2)

# Annotate points
for x, y in zip(service_calls_churn.index, service_calls_churn['Churn Rate']):
    plt.text(x, y + 0.5, f"{y:.1f}%", ha='center', fontsize=9, fontweight='bold')

plt.title('Churn Rate by Number of Customer Service Calls', fontweight = 'bold', fontsize =12 )
plt.xlabel('Number of Customer Service Calls')
plt.ylabel('Churn Rate (%)')
plt.xticks(service_calls_churn.index)
#plt.grid(True, linestyle='--', alpha=0.6)
plt.savefig('line_chart_service.png', bbox_inches='tight', dpi=300)
plt.tight_layout()
plt.show()
# Out:
# churn                      False     True
# customer service calls
# 0                       0.868006  0.131994
# 1                       0.896698  0.103302
# 2                       0.885375  0.114625
# 3                       0.897436  0.102564
# 4                       0.542169  0.457831
# 5                       0.393939  0.606061
# 6                       0.363636  0.636364
# 7                       0.444444  0.555556
# 8                       0.500000  0.500000
# 9                       0.000000  1.000000

# %% [markdown]
# ### Insight 7: Churn Rate by Customer Service Calls
#
# The line chart clearly shows a positive correlation between churn rate and the number of customer service calls.
# As the number of service interactions increases, the churn rate rises sharply, indicating that repeated contact with support is a strong signal of dissatisfaction.
#
# This suggests that customer service quality is a critical churn driver. Improving first-contact resolution, responsiveness, and satisfaction during service calls could have a direct impact on reducing churn.

# %% [markdown]
# #### Usage Cost Analysis

# %%
from matplotlib.colors import LinearSegmentedColormap

# 1. Create quartile-based cost buckets
data['cost_bucket'] = pd.qcut(data['total_charge'], q=4, labels=['Low', 'Medium', 'High', 'Very High'])

# 2. Filter only churned customers
churned_only = data[data['churn'] == 1]

# 3. Count churned customers by cost bucket
churn_counts = churned_only['cost_bucket'].value_counts().sort_index()

heat_data = pd.DataFrame(churn_counts).T  # Make it a row so heatmap can plot

# Create a colormap using a single hex color fading from white
custom_cmap = LinearSegmentedColormap.from_list("custom", ['#ffffff', '#617891'])

# Heatmap
plt.figure(figsize=(8, 2))
sns.heatmap(
    heat_data,
    annot=True,
    fmt='d',
    cmap=custom_cmap,
    linewidths=0.5,
    cbar=False,
    linecolor='white',
    annot_kws={'fontsize': 10, 'fontweight': 'bold'}
)

plt.title('Churn Count by Total Cost Bucket (Churned Only)', fontsize=12, fontweight='bold')
plt.xlabel('Cost Bucket')
plt.ylabel('')
plt.yticks([])
plt.savefig('heatmap_cost.png', bbox_inches='tight', dpi=300)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insight 8: Churn Count by Total Cost Bucket (Heatmap)
#
# The heatmap reveals a U-shaped pattern in churn distribution across total cost buckets:
# *   The highest churn count is observed in the "Very High" cost segment, indicating that high-billing customers are at risk, possibly due to pricing dissatisfaction or value concerns.
# *   Interestingly, the "Low" cost segment also shows a notable churn count, suggesting that new or low-usage customers may leave early, likely due to low engagement or unmet expectations.
#
# This aligns with earlier observations — long-term or heavy users may churn due to cost-related dissatisfaction, while newer or lighter users may churn early due to lack of value perception.
#
# Both groups require different interventions:
# *   High spenders may need better value communication or loyalty perks
# *   Low spenders might benefit from onboarding or engagement nudges.

# %% [markdown]
# ### **SUMMARY**
# - Heavy users and international plan subscribers churn more, likely due to cost concerns.
# - Mid-term customers churn the most — indicating dissatisfaction after using the service for a while.
# - Repeated customer service calls are strongly linked with churn, showing poor service experience as a major driver.
# - Surprisingly, some churn also occurs among low-usage or low-cost users — possibly due to lack of engagement.
#
# ➡️ **Conclusion**: Cost sensitivity and customer service dissatisfaction are the most critical churn drivers. Retention efforts should focus on:
# - Improving support quality and responsiveness
# - Offering value-based perks for international callers
# - Loyalty programs for mid-tenure and high-usage customers
